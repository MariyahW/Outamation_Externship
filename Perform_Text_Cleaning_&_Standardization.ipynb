# %% [markdown]
# <a href="https://colab.research.google.com/github/MariyahW/Outamation_Externship/blob/main/Perform_Text_Cleaning_%26_Standardization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import regex, requests, nltk, contractions, spell checker
# !pip install contractions
# !pip install pyspellchecker
from spellchecker import SpellChecker
import contractions
import nltk
from nltk.corpus import stopwords
import requests
#import string
import re

spell=SpellChecker()

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def speller(text):
  words=text.split()
  fixed=[]
  for word in words:
    corrected=spell.correction(word)
    fixed.append(corrected if corrected is not None else word)
  return " ".join(fixed)

def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return " ".join(filtered_words)

#bring in file that needs to be cleaned
url='https://raw.githubusercontent.com/MariyahW/Outamation_Externship/refs/heads/main/text_sample.txt'

# function to clean text
# this function first makes everything lowercase
# it will then remove everything that is not a number, letter, or a space
# then it will remove extra spacing, contractions, and stopwords, lastly spell check
def cleanText(text):
  text=text.lower()
  #trans=str.maketrans("","",string.punctuation)
  #text=text.translate(trans)
  text=re.sub(r"[^a-z0-9\.\s]","",text)
  text=re.sub(r"\s+"," ",text)
  text=contractions.fix(text)
  text=remove_stopwords(text)
  text=speller(text)
  return text

response= requests.get(url)
messy=response.text

text=cleanText(messy)

print(text)
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# the problematic text fly contains extra spaces special characters words misspelled encoding issues like the us problems prices inconsistent 29.99 29.99 us 2999. emails phone numbers may embedded contactdomain.com 1234567890. repeated punctuations removed along random symbols like . stopwords like appear often him tags might present divthis inside divide sometimes contractions expand cannot not random numeric values 123456 98765 2024.
